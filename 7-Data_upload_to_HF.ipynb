# %%
# !pip install datasets -q
# !pip install huggingface_hub -q

# %%
from datasets import (load_dataset,
                      Dataset,
                      DatasetDict)
import pandas as pd
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Replace by most recent version
filestamp = '1711835043'

# %%
news = Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/cleaned_data/{filestamp}_news.json'))
twitter = Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/cleaned_data/{filestamp}_twitter.json'))

# %%
news.push_to_hub('koen430/preprocessed_stock_news')
twitter.push_to_hub('koen430/preprocessed_stock_twitter')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/16 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# ...
# Creating parquet from Arrow format:   0%|          | 0/16 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/koen430/preprocessed_stock_twitter/commit/2fa2bc7c60700c14281c44700d8284e2d04aa58c', commit_message='Upload dataset', commit_description='', oid='2fa2bc7c60700c14281c44700d8284e2d04aa58c', pr_url=None, pr_revision=None, pr_num=None)

# %%
relevant_twitter_train = Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_twitter_train.json'))
relevant_twitter_val= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_twitter_val.json'))
relevant_twitter_test= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_twitter_test.json'))
twitter_train= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_twitter_train.json'))
twitter_val= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_twitter_val.json'))
twitter_test= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_twitter_test.json'))

# %%
relevant_twitter_data = DatasetDict()
relevant_twitter_data['train'] = relevant_twitter_train
relevant_twitter_data['val'] = relevant_twitter_val
relevant_twitter_data['test'] = relevant_twitter_test

relevant_twitter_data.push_to_hub('koen430/relevant_selected_stock_twitter')

random_twitter_data = DatasetDict()
random_twitter_data['train'] = twitter_train
random_twitter_data['val'] = twitter_val
random_twitter_data['test'] = twitter_test

random_twitter_data.push_to_hub('koen430/random_selected_stock_twitter')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/koen430/random_selected_stock_twitter/commit/b704261086e5b23a3f9eaa10769ef0fd002566d7', commit_message='Upload dataset', commit_description='', oid='b704261086e5b23a3f9eaa10769ef0fd002566d7', pr_url=None, pr_revision=None, pr_num=None)

# %%
relevant_news_train= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_news_train.json'))
relevant_news_val= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_news_val.json'))
relevant_news_test= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_news_test.json'))
news_train= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_news_train.json'))
news_val= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_news_val.json'))
news_test= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_news_test.json'))

# %%
relevant_news_data = DatasetDict()
relevant_news_data['train'] = relevant_news_train
relevant_news_data['val'] = relevant_news_val
relevant_news_data['test'] = relevant_news_test

relevant_news_data.push_to_hub('koen430/relevant_selected_stock_news')

random_news_data = DatasetDict()
random_news_data['train'] = news_train
random_news_data['val'] = news_val
random_news_data['test'] = news_test

random_news_data.push_to_hub('koen430/random_selected_stock_news')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/koen430/random_selected_stock_news/commit/8c9fce324d9b13f1e77cabc8569fc592329bca7c', commit_message='Upload dataset', commit_description='', oid='8c9fce324d9b13f1e77cabc8569fc592329bca7c', pr_url=None, pr_revision=None, pr_num=None)

# %%
relevant_mix_train= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_mix_train.json'))
relevant_mix_val= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_mix_val.json'))
relevant_mix_test= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/relevant_selection/{filestamp}_mix_test.json'))
mix_train= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_mix_train.json'))
mix_val= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_mix_val.json'))
mix_test= Dataset.from_pandas(pd.read_json(f'/content/drive/MyDrive/Thesis data/random_selection/{filestamp}_mix_test.json'))

# %%
relevant_mix_data = DatasetDict()
relevant_mix_data['train'] = relevant_mix_train
relevant_mix_data['val'] = relevant_mix_val
relevant_mix_data['test'] = relevant_mix_test

relevant_mix_data.push_to_hub('koen430/relevant_selected_stock_mix')

random_mix_data = DatasetDict()
random_mix_data['train'] = mix_train
random_mix_data['val'] = mix_val
random_mix_data['test'] = mix_test

random_mix_data.push_to_hub('koen430/random_selected_stock_mix')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/koen430/random_selected_stock_mix/commit/37a7415a3e4e279322778967b095090bdc72a7d9', commit_message='Upload dataset', commit_description='', oid='37a7415a3e4e279322778967b095090bdc72a7d9', pr_url=None, pr_revision=None, pr_num=None)
